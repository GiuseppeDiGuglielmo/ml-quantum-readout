# %%
#!source /data/Xilinx_no_Vitis/Vivado/2020.1/settings64.sh
# !vivado -version
# Out:
# Vivado v2020.1.1 (64-bit)
# SW Build 2960000 on Wed Aug  5 22:57:21 MDT 2020
# IP Build 2956692 on Thu Aug  6 01:41:30 MDT 2020
# Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.

# %%
import os 
import pickle
import hashlib

import pandas as pd

import hls4ml 
import numpy as np
import matplotlib.pyplot as plt 
from sklearn.metrics import accuracy_score
import keras
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, BatchNormalization, Dropout
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from tensorflow.keras.losses import CategoricalCrossentropy

from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning
import tensorflow_model_optimization as tfmot

from qkeras.qlayers import QDense, QActivation
from qkeras import QBatchNormalization
from qkeras.quantizers import quantized_bits, quantized_relu
from qkeras.utils import _add_supported_quantized_objects
from tensorflow.keras.models import load_model
from qkeras.utils import _add_supported_quantized_objects
# need updated tensorflow-model-optimization==0.8.0
os.environ['PATH'] = os.environ['XILINX_VIVADO'] + '/bin:' + os.environ['PATH']
# Out:
# 2024-10-04 08:18:13.243468: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-04 08:18:13.246012: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-04 08:18:13.289636: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-04 08:18:13.290358: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-04 08:18:13.874380: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARN: Unable to import optimizer(s) from expr_templates.py: No module named 'sympy'
# WARNING: Failed to import handlers from pooling.py: No module named 'torch'.
# WARNING: Failed to import handlers from convolution.py: No module named 'torch'.
# WARNING: Failed to import handlers from reshape.py: No module named 'torch'.
# WARNING: Failed to import handlers from merge.py: No module named 'torch'.
# WARNING: Failed to import handlers from core.py: No module named 'torch'.
# /home/giuseppe/miniconda3/envs/ml4qick-env/lib/python3.8/site-packages/hls4ml/converters/__init__.py:27: UserWarning: WARNING: Pytorch converter is not enabled!
#   warnings.warn("WARNING: Pytorch converter is not enabled!", stacklevel=1)

# %%
# Set the seed using keras.utils.set_random_seed. This will set:
# 1) `numpy` seed
# 2) backend random seed
# 3) `python` random seed
keras.utils.set_random_seed(812)

# %% [markdown]
# ## Setup data

# %%
dataset_date = '20230529'
#dataset_date = '20240528'

# %%
def one_hot_encode(data):
    y_encoded = np.zeros([data.shape[0],2], dtype=np.int32)
    for idx, x in enumerate(data):
        if x == 1:
            y_encoded[idx][1] = 1
        else:
            y_encoded[idx][0] = 1
    return y_encoded

# %%
#train_data_dir = "../data/malab_05282024/npz/"
#test_data_dir = "../data/malab_05282024/npz/"
train_data_dir = f'../data/qick_data/{dataset_date}/000_770/'
test_data_dir = f'../data/qick_data/{dataset_date}/000_770/'
start_location = 100
end_window = 500
window_size = 400

# %%
"""Loadning training split"""
#x_train_path = os.path.join(train_data_dir, f'0528_X_train_0_770.npy')
#y_train_path = os.path.join(train_data_dir, f'0528_y_train_0_770.npy')
x_train_path = os.path.join(train_data_dir, f'X_train_000_770.npy')
y_train_path = os.path.join(train_data_dir, f'y_train_000_770.npy')

assert os.path.exists(x_train_path), f"ERROR: File {x_train_path} does not exist."
assert os.path.exists(y_train_path), f"ERROR: File {y_train_path} does not exist."

X_train_val = np.load(x_train_path)
y_train_val = np.load(y_train_path)

# Insure same dataset is loaded
if dataset_date == '20240528':
    assert hashlib.md5(X_train_val).hexdigest() == 'b61226c86b7dee0201a9158455e08ffb',  "Checksum failed. Wrong file was loaded or file may be corrupted."
    assert hashlib.md5(y_train_val).hexdigest() == 'c59ce37dc7c73d2d546e7ea180fa8d31',  "Checksum failed. Wrong file was loaded or file may be corrupted."
else:
    assert hashlib.md5(X_train_val).hexdigest() == '0ab0f60cc85484a09ac3a963dff3f2b6',  "Checksum failed. Wrong file was loaded or file may be corrupted."
    assert hashlib.md5(y_train_val).hexdigest() == '4fd659c18a973f4742cb25fdca75f8b8',  "Checksum failed. Wrong file was loaded or file may be corrupted."

# Get readout window
X_train_val = X_train_val[:,start_location*2:end_window*2]
y_train_val = one_hot_encode(y_train_val)
assert len(X_train_val[0]) == (end_window-start_location)*2, f"ERROR: X_test sample size {len(X_train_val[0])} does not match (start window, end window) ({start_location},{end_window}) size."


print("Train Data Set:")
print(f"  X Path : {x_train_path}")
print(f"  y Path : {y_train_path}")
print(f"  Size : {len(X_train_val):,}")
print(f"  Shape : {X_train_val[0].shape}")
# Out:
# Train Data Set:
#   X Path : ../data/qick_data/20230529/000_770/X_train_000_770.npy
#   y Path : ../data/qick_data/20230529/000_770/y_train_000_770.npy
#   Size : 909,000
#   Shape : (800,)

# %%
"""Loading testing split"""
#x_test_path = os.path.join(test_data_dir, f'0528_X_test_0_770.npy')
#y_test_path = os.path.join(test_data_dir, f'0528_y_test_0_770.npy')
x_test_path = os.path.join(train_data_dir, f'X_test_000_770.npy')
y_test_path = os.path.join(train_data_dir, f'y_test_000_770.npy')

assert os.path.exists(x_test_path), f"ERROR: File {x_test_path} does not exist."
assert os.path.exists(y_test_path), f"ERROR: File {y_test_path} does not exist."

X_test = np.load(x_test_path)
y_test = np.load(y_test_path)

# Insure same dataset is loaded
if dataset_date == '20240528':
    assert hashlib.md5(X_test).hexdigest() == 'b7d85f42522a0a57e877422bc5947cde', "Checksum failed. Wrong file was loaded or file may be corrupted."
    assert hashlib.md5(y_test).hexdigest() == '8c9cce1821372380371ade5f0ccfd4a2', "Checksum failed. Wrong file was loaded or file may be corrupted."
else:
    assert hashlib.md5(X_test).hexdigest() == '678ec7a77105a7c05d7b269ee0ce57ec', "Checksum failed. Wrong file was loaded or file may be corrupted."
    assert hashlib.md5(y_test).hexdigest() == 'fdc9fe7b08d38399e70824eb131f8d07', "Checksum failed. Wrong file was loaded or file may be corrupted."

# Get readout window
X_test = X_test[:,start_location*2:end_window*2]
y_test = one_hot_encode(y_test)
assert len(X_test[0]) == (end_window-start_location)*2, f"ERROR: X_test sample size {len(X_test[0])} does not match (start window, end window) ({start_location},{end_window}) size."


print("Test Data Set:")
print(f"  X Path : {x_test_path}")
print(f"  y Path : {y_test_path}")
print(f"  Size : {len(X_test):,}" )
print(f"  Sample Shape : {X_test[0].shape}")
# Out:
# Test Data Set:
#   X Path : ../data/qick_data/20230529/000_770/X_test_000_770.npy
#   y Path : ../data/qick_data/20230529/000_770/y_test_000_770.npy
#   Size : 101,000
#   Sample Shape : (800,)

# %% [markdown]
# ## Build our model
# QKeras is "Quantized Keras" for deep heterogeneous quantization of ML models. We're using QDense layer instead of Dense. We're also training with model sparsity, since QKeras layers are prunable.

# %%
hidden_neurons = 8
input_shape = int((end_window-start_location)*2)

# %%
def get_model(input_shape, hidden=8, is_pruned=True):
    model = keras.models.Sequential()
    model.add(QDense(
        hidden, 
        activation='relu', 
        name='fc1',
        input_shape=(input_shape,), 
        kernel_quantizer=quantized_bits(6,0,alpha=1), bias_quantizer=quantized_bits(6,0,alpha=1)
    ))
    # model.add(BatchNormalization(name='batchnorm1'))
    model.add(QBatchNormalization(
            name='batchnorm1',
            gamma_quantizer=quantized_bits(6, 0, 1),
            mean_quantizer=quantized_bits(6, 0, 1),
            variance_quantizer=quantized_bits(6, 0, 1),
            beta_quantizer=quantized_bits(6, 0, 1),
    ))
    model.add(
        QDense(2, name='fc2', kernel_quantizer=quantized_bits(6,0,alpha=1), bias_quantizer=quantized_bits(6,0,alpha=1))
    )

    # adding pruning 
    if is_pruned == True:
        pruning_params = {'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.10, final_sparsity=0.50, begin_step=200, end_step=1000)}
        model = prune.prune_low_magnitude(model, **pruning_params)
    return model


model = get_model(input_shape=input_shape, hidden=hidden_neurons, is_pruned=False)
print(model.summary())
print('Input shape:', input_shape)
print('Number of hidden neurons:', hidden_neurons)
# Out:
# 2024-10-04 08:18:41.855441: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-10-04 08:18:41.865737: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1960] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  fc1 (QDense)                (None, 8)                 6408
#
#  batchnorm1 (QBatchNormaliz  (None, 8)                 32
#  ation)
#
#  fc2 (QDense)                (None, 2)                 18
#
# =================================================================
# Total params: 6458 (25.23 KB)
# Trainable params: 6442 (25.16 KB)
# Non-trainable params: 16 (64.00 Byte)
# _________________________________________________________________
# None
# Input shape: 800
# Number of hidden neurons: 8

# %% [markdown]
# ## Training

# %%
init_learning_rate = 1e-2
validation_split = 0.05  # 45,000 sample size 
batch_size = 1024*8
epochs = 150
early_stopping_patience = 20
checkpoint_dir = f'../checkpoints/scan_window_location_and_size_h{hidden_neurons}'
checkpoint_filename = 'qkeras_model_best.h5'
# checkpoint_filename = 'qkeras_model_best.weights.h5'

assert os.path.exists(checkpoint_dir), f'ERROR: Checkpoint directory {checkpoint_dir} does not exist.'

# %%
#########################
# 0. init callbacks
#########################
ckp_dir = os.path.join(checkpoint_dir, f'sl{start_location}_ws{window_size}_date{dataset_date}')
if os.path.exists(ckp_dir) == False: os.mkdir(ckp_dir)
print('Saving to', ckp_dir)

ckp_filename = os.path.join(ckp_dir, checkpoint_filename)
callbacks = [
    ModelCheckpoint(
        ckp_filename,
        monitor="val_loss",
        verbose=0,
        save_best_only=True,
        save_weights_only=True,
        save_freq="epoch",
    ),
    EarlyStopping(
        monitor='val_loss',
        patience=early_stopping_patience,
        restore_best_weights=False,
    ),
    pruning_callbacks.UpdatePruningStep(),
    # ReduceLROnPlateau(patience=early_stopping_patience, min_delta=1**-6),
]
# Out:
# Saving to ../checkpoints/scan_window_location_and_size_h8/sl100_ws400_date20230529

# %%
if True:
    #########################
    # 1. declare model 
    #########################
    opt = Adam(learning_rate=init_learning_rate)
    model = get_model(input_shape=window_size*2, is_pruned=True)
    model.compile(
        optimizer=opt, 
        loss=CategoricalCrossentropy(from_logits=True), 
        metrics=['accuracy']
    )

    #########################
    # 3. train 
    #########################
    history = model.fit(
        X_train_val, 
        y_train_val, 
        batch_size=batch_size,
        epochs=epochs, 
        validation_split=validation_split, 
        shuffle=True, 
        callbacks=callbacks,
    )

    # Save the history dictionary
    with open(os.path.join(ckp_dir, 'qkeras_training_history.pkl'), 'wb') as f:
        pickle.dump(history.history, f)

    #########################
    # 3. compute fidelity 
    #########################
    y_pred = model.predict(X_test)
    test_acc = accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))

    print('\n===================================')
    print(f'Start location = {start_location}, Window size = {window_size}')
    print('    Accuracy', test_acc)
    print('    Fidelity', test_acc*2-1)
# Out:
# Epoch 1/150
# 106/106 [==============================] - 3s 11ms/step - loss: 0.2422 - accuracy: 0.9251 - val_loss: 0.2026 - val_accuracy: 0.9424
# Epoch 2/150
# 106/106 [==============================] - 1s 6ms/step - loss: 0.1671 - accuracy: 0.9588 - val_loss: 0.1683 - val_accuracy: 0.9582
# Epoch 3/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1647 - accuracy: 0.9600 - val_loss: 0.1746 - val_accuracy: 0.9542
# Epoch 4/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1627 - accuracy: 0.9606 - val_loss: 0.1667 - val_accuracy: 0.9594
# Epoch 5/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1621 - accuracy: 0.9607 - val_loss: 0.1654 - val_accuracy: 0.9596
# Epoch 6/150
# 106/106 [==============================] - 1s 6ms/step - loss: 0.1624 - accuracy: 0.9606 - val_loss: 0.1652 - val_accuracy: 0.9598
# Epoch 7/150
# 106/106 [==============================] - 1s 6ms/step - loss: 0.1619 - accuracy: 0.9608 - val_loss: 0.1647 - val_accuracy: 0.9595
# Epoch 8/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1618 - accuracy: 0.9609 - val_loss: 0.1646 - val_accuracy: 0.9598
# Epoch 9/150
# 106/106 [==============================] - 1s 7ms/step - loss: 0.1617 - accuracy: 0.9609 - val_loss: 0.1647 - val_accuracy: 0.9598
# Epoch 10/150
# 106/106 [==============================] - 1s 7ms/step - loss: 0.1615 - accuracy: 0.9609 - val_loss: 0.1646 - val_accuracy: 0.9595
# Epoch 11/150
# 106/106 [==============================] - 1s 7ms/step - loss: 0.1614 - accuracy: 0.9609 - val_loss: 0.1646 - val_accuracy: 0.9597
# Epoch 12/150
# 106/106 [==============================] - 1s 6ms/step - loss: 0.1614 - accuracy: 0.9609 - val_loss: 0.1645 - val_accuracy: 0.9597
# Epoch 13/150
# 106/106 [==============================] - 1s 6ms/step - loss: 0.1613 - accuracy: 0.9609 - val_loss: 0.1646 - val_accuracy: 0.9597
# Epoch 14/150
# 106/106 [==============================] - 1s 6ms/step - loss: 0.1613 - accuracy: 0.9609 - val_loss: 0.1645 - val_accuracy: 0.9598
# Epoch 15/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1613 - accuracy: 0.9609 - val_loss: 0.1643 - val_accuracy: 0.9596
# Epoch 16/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1613 - accuracy: 0.9610 - val_loss: 0.1644 - val_accuracy: 0.9598
# Epoch 17/150
# 106/106 [==============================] - 1s 6ms/step - loss: 0.1612 - accuracy: 0.9609 - val_loss: 0.1647 - val_accuracy: 0.9595
# Epoch 18/150
# 106/106 [==============================] - 1s 7ms/step - loss: 0.1612 - accuracy: 0.9609 - val_loss: 0.1646 - val_accuracy: 0.9598
# Epoch 19/150
# 106/106 [==============================] - 1s 7ms/step - loss: 0.1612 - accuracy: 0.9609 - val_loss: 0.1644 - val_accuracy: 0.9597
# Epoch 20/150
# 106/106 [==============================] - 1s 8ms/step - loss: 0.1612 - accuracy: 0.9609 - val_loss: 0.1645 - val_accuracy: 0.9599
# Epoch 21/150
# 106/106 [==============================] - 1s 8ms/step - loss: 0.1611 - accuracy: 0.9609 - val_loss: 0.1646 - val_accuracy: 0.9598
# Epoch 22/150
# 106/106 [==============================] - 1s 7ms/step - loss: 0.1610 - accuracy: 0.9609 - val_loss: 0.1647 - val_accuracy: 0.9598
# Epoch 23/150
# 106/106 [==============================] - 1s 7ms/step - loss: 0.1611 - accuracy: 0.9609 - val_loss: 0.1647 - val_accuracy: 0.9599
# Epoch 24/150
# 106/106 [==============================] - 1s 7ms/step - loss: 0.1610 - accuracy: 0.9609 - val_loss: 0.1648 - val_accuracy: 0.9599
# Epoch 25/150
# 106/106 [==============================] - 1s 8ms/step - loss: 0.1609 - accuracy: 0.9610 - val_loss: 0.1644 - val_accuracy: 0.9600
# Epoch 26/150
# 106/106 [==============================] - 1s 10ms/step - loss: 0.1609 - accuracy: 0.9609 - val_loss: 0.1646 - val_accuracy: 0.9600
# Epoch 27/150
# 106/106 [==============================] - 1s 7ms/step - loss: 0.1608 - accuracy: 0.9609 - val_loss: 0.1644 - val_accuracy: 0.9600
# Epoch 28/150
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1609 - accuracy: 0.9610 - val_loss: 0.1644 - val_accuracy: 0.9599
# Epoch 29/150
# 106/106 [==============================] - 1s 8ms/step - loss: 0.1608 - accuracy: 0.9609 - val_loss: 0.1638 - val_accuracy: 0.9597
# Epoch 30/150
# 106/106 [==============================] - 1s 7ms/step - loss: 0.1607 - accuracy: 0.9609 - val_loss: 0.1643 - val_accuracy: 0.9601
# Epoch 31/150
# 106/106 [==============================] - 1s 6ms/step - loss: 0.1607 - accuracy: 0.9609 - val_loss: 0.1642 - val_accuracy: 0.9601
# Epoch 32/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1606 - accuracy: 0.9609 - val_loss: 0.1641 - val_accuracy: 0.9600
# Epoch 33/150
# 106/106 [==============================] - 1s 6ms/step - loss: 0.1606 - accuracy: 0.9610 - val_loss: 0.1640 - val_accuracy: 0.9600
# Epoch 34/150
# 106/106 [==============================] - 1s 7ms/step - loss: 0.1606 - accuracy: 0.9609 - val_loss: 0.1642 - val_accuracy: 0.9599
# Epoch 35/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1606 - accuracy: 0.9610 - val_loss: 0.1643 - val_accuracy: 0.9602
# Epoch 36/150
# 106/106 [==============================] - 1s 6ms/step - loss: 0.1605 - accuracy: 0.9609 - val_loss: 0.1641 - val_accuracy: 0.9600
# Epoch 37/150
# 106/106 [==============================] - 1s 6ms/step - loss: 0.1605 - accuracy: 0.9610 - val_loss: 0.1645 - val_accuracy: 0.9599
# Epoch 38/150
# 106/106 [==============================] - 1s 6ms/step - loss: 0.1604 - accuracy: 0.9609 - val_loss: 0.1640 - val_accuracy: 0.9599
# Epoch 39/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1604 - accuracy: 0.9609 - val_loss: 0.1641 - val_accuracy: 0.9596
# Epoch 40/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1605 - accuracy: 0.9610 - val_loss: 0.1639 - val_accuracy: 0.9599
# Epoch 41/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1604 - accuracy: 0.9610 - val_loss: 0.1639 - val_accuracy: 0.9598
# Epoch 42/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1604 - accuracy: 0.9609 - val_loss: 0.1640 - val_accuracy: 0.9599
# Epoch 43/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1603 - accuracy: 0.9610 - val_loss: 0.1643 - val_accuracy: 0.9597
# Epoch 44/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1603 - accuracy: 0.9609 - val_loss: 0.1642 - val_accuracy: 0.9599
# Epoch 45/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1603 - accuracy: 0.9609 - val_loss: 0.1639 - val_accuracy: 0.9599
# Epoch 46/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1603 - accuracy: 0.9610 - val_loss: 0.1641 - val_accuracy: 0.9597
# Epoch 47/150
# 106/106 [==============================] - 1s 5ms/step - loss: 0.1603 - accuracy: 0.9610 - val_loss: 0.1643 - val_accuracy: 0.9596
# Epoch 48/150
# 106/106 [==============================] - 1s 6ms/step - loss: 0.1603 - accuracy: 0.9610 - val_loss: 0.1643 - val_accuracy: 0.9597
# Epoch 49/150
# 106/106 [==============================] - 1s 9ms/step - loss: 0.1602 - accuracy: 0.9610 - val_loss: 0.1641 - val_accuracy: 0.9597
# 3157/3157 [==============================] - 5s 1ms/step
#
# ===================================
# Start location = 100, Window size = 400
#     Accuracy 0.9601485148514851
#     Fidelity 0.9202970297029702

# %% [markdown]
# ## Check performance

# %%
ckp_filename = os.path.join(ckp_dir, checkpoint_filename)
ckp_filename
# Out:
# '../checkpoints/scan_window_location_and_size_h8/sl100_ws400_date20230529/qkeras_model_best.h5'

# %%
checkpoint_model = get_model(input_shape=input_shape, hidden=hidden_neurons, is_pruned=True)
checkpoint_model.load_weights(ckp_filename)

y_pred = checkpoint_model.predict(X_test)
test_acc = accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))

print(f"Keras  Accuracy: {test_acc}")
print(f"Keras  Fidelity: {test_acc*2-1}")
# Out:
# 3157/3157 [==============================] - 4s 1ms/step
# Keras  Accuracy: 0.959980198019802
# Keras  Fidelity: 0.9199603960396039

# %% [markdown]
# ## Check sparsity

# %%
num_layers = len(checkpoint_model.layers)
print(f'Number of layers: {num_layers}')


for idx in range(num_layers):
    w = checkpoint_model.layers[idx].weights[0].numpy()
    h, b = np.histogram(w, bins=100)

    # plot weight distribution
    plt.figure(figsize=(7, 7))
    plt.bar(b[:-1], h, width=b[1] - b[0])
    plt.semilogy()
    plt.savefig(f'model-dist-idx{idx}.png')

    print('% of zeros = {}'.format(np.sum(w == 0) / np.size(w)))


checkpoint_model = strip_pruning(checkpoint_model)  # remove prune layers for hls4ml parsing 
checkpoint_model.save_weights(ckp_filename)  # save as weights only for keras tracing (cannot directly pass strip_pruned model)
checkpoint_model = get_model(input_shape=input_shape, hidden=hidden_neurons, is_pruned=False)
checkpoint_model.load_weights(ckp_filename)
# Out:
# Number of layers: 3
# % of zeros = 0.5
# % of zeros = 0.0
# % of zeros = 0.5

# %% [markdown]
# ## HLS4ML

# %%
import sys 
sys.path.append("../utils")
from config import print_dict

from tensorflow.keras.models import load_model
from qkeras.utils import _add_supported_quantized_objects

# %%
# Create HLS configuration 
hls_config = {}
hls_config['Model'] = {}
hls_config['Model']['Precision'] = 'ap_fixed<16,6>'  # Default precision
#hls_config['Model']['ReuseFactor'] = 1  # fully parallelized 
hls_config['Model']['ReuseFactor'] = 64
hls_config['Model']['Strategy'] = 'Resource'

hls_config['LayerName'] = {}
keras_layers = ['fc1', 'fc1_relu', 'batchnorm1', 'fc2', 'fc2_linear']
for layer in keras_layers:
    hls_config['LayerName'][layer] = {}
    hls_config['LayerName'][layer]['Precision'] = {}
    hls_config['LayerName'][layer]['Trace'] = True

# Input - ZCU216 uses 14-bit ADCS 
hls_config['LayerName']['fc1_input'] = {}
hls_config['LayerName']['fc1_input']['Precision'] = {}
hls_config['LayerName']['fc1_input']['Trace'] = False
hls_config['LayerName']['fc1_input']['Precision'] = 'ap_fixed<14,14>' 
# Fc1
hls_config['LayerName']['fc1']['Precision']['result'] = 'ap_fixed<17,17>'
hls_config['LayerName']['fc1']['accum_t'] = 'ap_fixed<17,17>'
# Fc1 relu
hls_config['LayerName']['fc1_relu']['Precision']['result'] = 'ap_fixed<17,17>'

# Batchnormalization
hls_config['LayerName']['batchnorm1']['Precision']['scale'] = 'ap_fixed<24,4>'
hls_config['LayerName']['batchnorm1']['Precision']['bias'] = 'ap_fixed<24,4>'
hls_config['LayerName']['batchnorm1']['Precision']['result'] = 'ap_fixed<24,4>'
hls_config['LayerName']['batchnorm1']['accum_t'] = 'ap_fixed<24,4>'

# Fc2
hls_config['LayerName']['fc2']['Precision']['result'] = 'ap_fixed<8,5>'
hls_config['LayerName']['fc2']['accum_t'] = 'ap_fixed<8,5>'

# Fc2
hls_config['LayerName']['fc2_linear']['Precision']['result'] = 'ap_fixed<8,5>'

print_dict(hls_config)
# Out:
# Model
#   Precision:         ap_fixed<16,6>
#   ReuseFactor:       64
#   Strategy:          Resource
# LayerName
#   fc1
#     Precision
#       result:        ap_fixed<17,17>
#     Trace:           True
#     accum_t:         ap_fixed<17,17>
#   fc1_relu
#     Precision
#       result:        ap_fixed<17,17>
#     Trace:           True
#   batchnorm1
#     Precision
#       scale:         ap_fixed<24,4>
#       bias:          ap_fixed<24,4>
#       result:        ap_fixed<24,4>
#     Trace:           True
#     accum_t:         ap_fixed<24,4>
#   fc2
#     Precision
#       result:        ap_fixed<8,5>
#     Trace:           True
#     accum_t:         ap_fixed<8,5>
#   fc2_linear
#     Precision
#       result:        ap_fixed<8,5>
#     Trace:           True
#   fc1_input
#     Precision:       ap_fixed<14,14>
#     Trace:           False

# %% [markdown]
# ### Build HLS model

# %%
output_dir = f'../hls4ml_projects/sl-{start_location}_ws-{window_size}_date-{dataset_date}'
xilinx_part = 'xczu49dr-ffvf1760-2-e'
#io_type = 'io_parallel'
io_type = 'io_stream'
clock_period = 3.225  # 3.225ns (307.2 MHz)
hls_fig = os.path.join(output_dir, 'model.png')
backend = 'VivadoAccelerator' 
interface = 'axi_stream'
driver = 'python'
board = 'zcu216'

# %%
hls_model = hls4ml.converters.convert_from_keras_model(
    model=checkpoint_model,
    hls_config=hls_config,
    output_dir=output_dir,
    part=xilinx_part,
    io_type=io_type,
    clock_period=clock_period,
    backend=backend,
    board=board,
    interface=interface,
    #driver=driver,
    project_name='NN'
)

print(f"Creating hls4ml project directory {output_dir}")
hls_model.compile()  # Must compile for C Sim. 

# Visualize model
hls4ml.utils.plot_model(
    hls_model, show_shapes=True, show_precision=True, to_file=hls_fig 
)
# Out:
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: InputLayer, input shapes: [[None, 800]], output shape: [None, 800]
# Layer name: fc1, layer type: QDense, input shapes: [[None, 800]], output shape: [None, 8]
# Layer name: batchnorm1, layer type: QBatchNormalization, input shapes: [[None, 8]], output shape: [None, 8]
# Layer name: fc2, layer type: QDense, input shapes: [[None, 8]], output shape: [None, 2]
# Creating HLS model
# WARNING: Changing pipeline style to "dataflow".
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "fc1" (Dense)
# WARNING: Config parameter "accum_t" overwrites an existing attribute in layer "fc2" (Dense)
# WARNING: Invalid ReuseFactor=64 in layer "fc1".Using ReuseFactor=50 instead. Valid ReuseFactor(s): 1,2,4,5,8,10,16,20,25,32,40,50,80,100,160,200,400,800,1600,3200,6400.
# WARNING: Invalid ReuseFactor=64 in layer "fc2".Using ReuseFactor=16 instead. Valid ReuseFactor(s): 1,2,4,8,16.
# Creating hls4ml project directory ../hls4ml_projects/sl-100_ws-400_date-20230529
# Writing HLS project
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /home/giuseppe/miniconda3/envs/ml4qick-env/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done

# %% [markdown]
# ## Check performance

# %%
def save_array_to_dat(data, top_nrows, bottom_nrows, filename):
    print('Save top {} rows and bottom {} rows in file {}'.format(top_nrows, bottom_nrows, filename))
    with open(filename, 'w') as file:
        for row in data[:top_nrows]:
            file.write(' '.join(map(str, row)) + '\n')
        for row in data[-bottom_nrows:]:
            file.write(' '.join(map(str, row)) + '\n')

# %%
# Trace output 
y_hls_values = hls_model.predict(np.ascontiguousarray(X_test.astype(np.float32)))
y_hls = np.argmax(y_hls_values, axis=1)

keras_acc = accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
hls_acc = accuracy_score(np.argmax(y_test, axis=1), y_hls)

print(f'Keras Acc: {keras_acc*100:.5}%')
print(f'Keras Fidelity: {(keras_acc*2-1) * 100:.5}%')
print(f'HLS Acc: {hls_acc*100:.5}:%')
print(f'HLS Fidelity: {(hls_acc*2-1) * 100:.5}:%')
# Out:
# Keras Acc: 95.998%
# Keras Fidelity: 91.996%
# HLS Acc: 60.062:%
# HLS Fidelity: 20.125:%

# %%
nrows = 10

# Save X_test for testing
save_array_to_dat(X_test, nrows, nrows, "X_test.dat")
save_array_to_dat(y_test, nrows, nrows, "y_test.dat")
save_array_to_dat(y_hls_values, nrows, nrows, "y_hls.dat")
# Out:
# Save top 10 rows and bottom 10 rows in file X_test.dat
# Save top 10 rows and bottom 10 rows in file y_test.dat
# Save top 10 rows and bottom 10 rows in file y_hls.dat

# %% [markdown]
# ### Collect traces and compare

# %%
_, hls_trace = hls_model.trace(np.ascontiguousarray(X_test.astype(np.float32))) 
keras_trace = hls4ml.model.profiling.get_ymodel_keras(checkpoint_model, X_test) 

print(f'HLS Keys: {hls_trace.keys()}')
print(f'Keras Keys: {keras_trace.keys()}')
# Out:
# Recompiling NN with tracing
# Writing HLS project
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# /home/giuseppe/miniconda3/envs/ml4qick-env/lib/python3.8/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done
# 3157/3157 [==============================] - 3s 952us/step
# 3157/3157 [==============================] - 5s 1ms/step
# Done taking outputs for Keras model.
# HLS Keys: dict_keys(['fc1', 'fc1_relu', 'batchnorm1', 'fc2'])
# Keras Keys: dict_keys(['fc1', 'fc1_relu', 'batchnorm1', 'fc2'])

# %%
idx = 0

hls_layers = hls_trace.keys()
keras_layers = list(keras_trace.keys())
# keras_layers = ['q_dense_1', 'q_batch_normalization_1', 'fc2']

for hls_layer, keras_layer in zip(hls_layers, keras_layers):
    keras_layer, hls_layer = keras_trace[keras_layer], hls_trace[hls_layer]
    try:
        diff = np.average(np.abs(keras_layer - hls_layer ))
        print(f'Layer(s): {list(hls_trace.keys())[idx]}', '\t\t', diff)
        
        plt.figure(figsize=(7, 5))

        plt.scatter(hls_layer.flatten(), keras_layer.flatten())
        min_x = min(keras_layer.min(), hls_layer.min())
        max_x = min(keras_layer.max(), hls_layer.max())

        onnx_min, onnx_max = keras_layer.flatten().min(), keras_layer.flatten().max()
        hls_min, hls_max = hls_layer.flatten().min(), hls_layer.flatten().max()
        
        print(f'hls/keras min: {hls_min}/{onnx_min}')
        print(f'hls/keras max: {hls_max}/{onnx_max}')
        
        plt.plot([min_x, max_x], [min_x, max_x], c='red')
        plt.axhline(min_x, c='red')
        plt.axhline(max_x, c='red')

        plt.title(f'(hls) {list(hls_trace.keys())[idx]} -- (keras) {list(keras_trace.keys())[idx]}')
        plt.xlabel(f'hls4ml - [{hls_min:.3f},  {hls_max:.3f}]')
        plt.ylabel(f'keras - [{onnx_min:.3f},  {onnx_max:.3f}]')
        plt.yscale('linear')
        idx += 1
    except Exception as e:
        print(e)
# Out:
# Layer(s): fc1 		 4197.472
# hls/keras min: -65536.0/-59168.125
# hls/keras max: 65535.0/106007.65625
# Layer(s): fc1_relu 		 2345.3108
# hls/keras min: 0.0/0.0
# hls/keras max: 65535.0/106007.65625
# Layer(s): batchnorm1 		 0.7158783
# hls/keras min: -1.544886589050293/-0.468789279460907
# hls/keras max: 3.4417362213134766/4.214264392852783
# Layer(s): fc2 		 2.653141
# hls/keras min: -5.625/-5.829246997833252
# hls/keras max: 4.625/5.398536682128906

# %% [markdown]
# ## Synthesize

# %%
reports = hls_model.build(
    csim=False,
    synth=True,
    cosim=False,
    export=False,
    vsynth=True,
)
# Out:
# ****** Vivado(TM) HLS - High-Level Synthesis from C, C++ and SystemC v2020.1.1 (64-bit)
#   **** SW Build 2960000 on Wed Aug  5 22:57:21 MDT 2020
#   **** IP Build 2956692 on Thu Aug  6 01:41:30 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vivado/2020.1/scripts/vivado_hls/hls.tcl -notrace
# INFO: Applying HLS Y2K22 patch v1.2 for IP revision
# INFO: [HLS 200-10] Running '/tools/Xilinx/Vivado/2020.1/bin/unwrapped/lnx64.o/vivado_hls'
# INFO: [HLS 200-10] For user 'giuseppe' on host 'thorin' (Linux_x86_64 version 5.14.0-1048-oem) on Fri Oct 04 08:20:42 PDT 2024
# INFO: [HLS 200-10] On os Ubuntu 22.04.5 LTS
# INFO: [HLS 200-10] In directory '/extras/home/gdg/research/projects/quantum/qick_dev/submodules/ml-quantum-readout/hls4ml_projects/sl-100_ws-400_date-20230529'
# Sourcing Tcl script 'build_prj.tcl'
# INFO: [HLS 200-10] Creating and opening project '/extras/home/gdg/research/projects/quantum/qick_dev/submodules/ml-quantum-readout/hls4ml_projects/sl-100_ws-400_date-20230529/NN_prj'.
# INFO: [HLS 200-10] Adding design file 'firmware/NN_axi.cpp' to the project
# INFO: [HLS 200-10] Adding design file 'firmware/NN.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'NN_test.cpp' to the project
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-10] Creating and opening solution '/extras/home/gdg/research/projects/quantum/qick_dev/submodules/ml-quantum-readout/hls4ml_projects/sl-100_ws-400_date-20230529/NN_prj/solution1'.
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# INFO: [XFORM 203-1161] The maximum of name length is set into 80.
# INFO: [HLS 200-10] Setting target device to 'xczu49dr-ffvf1760-2-e'
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 3.225ns.
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 0.403ns.
# ***** C/RTL SYNTHESIS *****
# INFO: [SCHED 204-61] Option 'relax_ii_for_timing' is enabled, will increase II to preserve clock frequency constraints.
# INFO: [HLS 200-10] Analyzing design file 'firmware/NN.cpp' ...
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/NN.cpp:37:65
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/NN.cpp:37:69
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/NN.cpp:51:71
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/NN.cpp:51:75
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/NN.cpp:56:70
# WARNING: [HLS 214-113] Either use an argument of the function or declare the variable inside the dataflow loop body: firmware/NN.cpp:56:74
# WARNING: [HLS 200-471] Dataflow form checks found 6 issue(s) in file firmware/NN.cpp
# INFO: [HLS 200-10] Analyzing design file 'firmware/NN_axi.cpp' ...
# WARNING: [HLS 214-114] Since the only kind of statements allowed in a canonical dataflow region are variable declarations and function calls, the compiler may not be able to correctly handle the region: firmware/NN_axi.cpp:17:2
# WARNING: [HLS 214-114] Since the only kind of statements allowed in a canonical dataflow region are variable declarations and function calls, the compiler may not be able to correctly handle the region: firmware/NN_axi.cpp:29:5
# WARNING: [HLS 200-471] Dataflow form checks found 2 issue(s) in file firmware/NN_axi.cpp
# INFO: [HLS 200-111] Finished Linking Time (s): cpu = 00:00:28 ; elapsed = 00:00:30 . Memory (MB): peak = 1583.844 ; gain = 1161.777 ; free physical = 12075 ; free virtual = 267081
# INFO: [HLS 200-111] Finished Checking Pragmas Time (s): cpu = 00:00:28 ; elapsed = 00:00:30 . Memory (MB): peak = 1583.844 ; gain = 1161.777 ; free physical = 12075 ; free virtual = 267081
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:136) in function 'void nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(FORWARD_REFERENCE*, FORWARD_REFERENCE*, FORWARD_REFERENCE::weight_t*, FORWARD_REFERENCE::bias_t*)' completely with a factor of 1.
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 800u>::operator[]' into 'NN_axi' (firmware/NN_axi.cpp:21).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 800u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 800u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>' (firmware/nnet_utils/nnet_dense_stream.h:44).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_leq_nin<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_resource.h:56).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_leq_nin<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' into 'nnet::dense_resource<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_resource.h:253).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' into 'nnet::dense_resource<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_resource.h:79->firmware/nnet_utils/nnet_dense_resource.h:253).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' into 'nnet::dense_wrapper<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_stream.h:21).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config3>' (firmware/nnet_utils/nnet_activation_stream.h:54).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config3>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config3>' (firmware/nnet_utils/nnet_activation_stream.h:52).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[]' into 'nnet::relu<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config3>' (firmware/nnet_utils/nnet_activation_stream.h:51).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 800u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>' (firmware/nnet_utils/nnet_dense_stream.h:60).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, 2u>, config5>' (firmware/nnet_utils/nnet_dense_stream.h:44).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>::operator[]' into 'nnet::normalize<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>' (firmware/nnet_utils/nnet_batchnorm_stream.h:41).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::normalize<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>' (firmware/nnet_utils/nnet_batchnorm_stream.h:42).
# INFO: [XFORM 203-603] Inlining function 'nnet::product::mult<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<6, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product' into 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' (firmware/nnet_utils/nnet_dense_resource.h:139).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource_rf_gt_nin_rem0<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' into 'nnet::dense_resource<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' (firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::cast<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' into 'nnet::dense_resource<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' (firmware/nnet_utils/nnet_dense_resource.h:158->firmware/nnet_utils/nnet_dense_resource.h:255).
# INFO: [XFORM 203-603] Inlining function 'nnet::dense_resource<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' into 'nnet::dense_wrapper<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' (firmware/nnet_utils/nnet_dense_stream.h:21).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, 2u>::operator[]' into 'NN_axi' (firmware/NN_axi.cpp:33).
# INFO: [XFORM 203-603] Inlining function 'nnet::array<ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, 2u>::operator[]' into 'nnet::dense<nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, 2u>, config5>' (firmware/nnet_utils/nnet_dense_stream.h:60).
# INFO: [HLS 200-111] Finished Standard Transforms Time (s): cpu = 00:00:31 ; elapsed = 00:00:33 . Memory (MB): peak = 1583.844 ; gain = 1161.777 ; free physical = 12005 ; free virtual = 267022
# INFO: [HLS 200-10] Checking synthesizability ...
# WARNING: [SYNCHK 200-23] firmware/NN_axi.cpp:33: variable-indexed range selection may cause suboptimal QoR.
# INFO: [SYNCHK 200-10] 0 error(s), 1 warning(s).
# INFO: [HLS 200-111] Finished Checking Synthesizability Time (s): cpu = 00:00:32 ; elapsed = 00:00:33 . Memory (MB): peak = 1583.844 ; gain = 1161.777 ; free physical = 11999 ; free virtual = 267018
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' on argument 'res_stream.V.data.V' . This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' on argument 'data_stream.V.data.V' . This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' (firmware/NN.cpp:12:1) on argument 'fc1_input.V.data.V' (firmware/NN.cpp:7). This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-803] Cannot specify interface mode 'axis' (firmware/NN.cpp:12:96) on argument 'layer5_out.V.data.V' (firmware/NN.cpp:8). This interface directive will be discarded. Please apply it on an argument of top module.
# WARNING: [XFORM 203-1103] Ignored data pack directive on non-struct variable 'out.data' (firmware/NN_axi.cpp:3).
# WARNING: [XFORM 203-1103] Ignored data pack directive on non-struct variable 'in.data' (firmware/NN_axi.cpp:3).
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_activation_stream.h:45) into a 136-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'out_data.data.V' (firmware/nnet_utils/nnet_batchnorm_stream.h:29) into a 192-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_dense_stream.h:55) into a 16-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'res_pack.data.V' (firmware/nnet_utils/nnet_dense_stream.h:55) into a 136-bit variable.
# INFO: [XFORM 203-1101] Packing variable 'ctype.data.V' (firmware/NN_axi.cpp:18) into a 11200-bit variable.
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::relu<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config3>' (firmware/nnet_utils/nnet_activation_stream.h:41:42).
# INFO: [XFORM 203-502] Unrolling all loops for pipelining in function 'nnet::normalize<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>' (firmware/nnet_utils/nnet_batchnorm_stream.h:18:43).
# INFO: [XFORM 203-502] Unrolling small iteration loop 'Loop-1' (firmware/NN_axi.cpp:17) in function 'NN_axi' automatically.
# INFO: [XFORM 203-502] Unrolling all sub-loops inside loop 'ReuseLoop' (firmware/nnet_utils/nnet_dense_resource.h:43) in function 'nnet::dense_wrapper<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' for pipelining.
# INFO: [HLS 200-489] Unrolling loop 'ReLUPackLoop' (firmware/nnet_utils/nnet_activation_stream.h:49) in function 'nnet::relu<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config3>' completely with a factor of 8.
# INFO: [HLS 200-489] Unrolling loop 'BatchNormpack' (firmware/nnet_utils/nnet_batchnorm_stream.h:33) in function 'nnet::normalize<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>' completely with a factor of 8.
# INFO: [HLS 200-489] Unrolling loop 'DataPack' (firmware/nnet_utils/nnet_dense_stream.h:42) in function 'nnet::dense<nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, 2u>, config5>' completely with a factor of 8.
# INFO: [HLS 200-489] Unrolling loop 'ResPack' (firmware/nnet_utils/nnet_dense_stream.h:58) in function 'nnet::dense<nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, 2u>, config5>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'DataPack' (firmware/nnet_utils/nnet_dense_stream.h:42) in function 'nnet::dense<nnet::array<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 800u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>' completely with a factor of 800.
# INFO: [HLS 200-489] Unrolling loop 'ResPack' (firmware/nnet_utils/nnet_dense_stream.h:58) in function 'nnet::dense<nnet::array<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 800u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>' completely with a factor of 8.
# INFO: [HLS 200-489] Unrolling loop 'Loop-1' (firmware/NN_axi.cpp:17) in function 'NN_axi' completely with a factor of 1.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:108) in function 'nnet::dense_wrapper<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:156) in function 'nnet::dense_wrapper<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 2.
# INFO: [HLS 200-489] Unrolling loop 'InitAccum' (firmware/nnet_utils/nnet_dense_resource.h:37) in function 'nnet::dense_wrapper<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 8.
# INFO: [HLS 200-489] Unrolling loop 'MultLoop' (firmware/nnet_utils/nnet_dense_resource.h:52) in function 'nnet::dense_wrapper<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 128.
# INFO: [HLS 200-489] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_resource.h:77) in function 'nnet::dense_wrapper<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 8.
# WARNING: [XFORM 203-135] Cannot reshape array 'w5.V' : incorrect reshape factor 1.
# WARNING: [XFORM 203-135] Cannot reshape array 'w5.V' : incorrect reshape factor 1.
# INFO: [XFORM 203-131] Reshaping array 'w2.V'  in dimension 1 with a block factor of 128.
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer2_out.V.data.V' (firmware/NN.cpp:35) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer3_out.V.data.V' (firmware/NN.cpp:42) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'layer4_out.V.data.V' (firmware/NN.cpp:49) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'out_local.V.data.V' (firmware/NN_axi.cpp:12) .
# INFO: [XFORM 203-102] Automatically partitioning streamed array 'in_local.V.data.V' .
# INFO: [XFORM 203-101] Partitioning array 'tmp.data.V' in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 's4.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'b4.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'tmp.data.V' in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'data.V' (firmware/nnet_utils/nnet_dense_stream.h:29) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'res.V' (firmware/nnet_utils/nnet_dense_stream.h:32) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'tmp.data.V' in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'data.V' (firmware/nnet_utils/nnet_dense_stream.h:29) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'res'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'tmp.data.V' in dimension 1 completely.
# WARNING: [XFORM 203-104] Completely partitioning array 'tmp.data.V' accessed through non-constant indices on dimension 1 (firmware/NN_axi.cpp:24:9), which may result in long runtime and suboptimal QoR due to large multiplexers. Please consider wrapping the array access into a function or using a register file core instead.
# INFO: [XFORM 203-101] Partitioning array 'b5.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'acc.V' (firmware/nnet_utils/nnet_dense_resource.h:104) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'b2.V'  in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'acc.V' (firmware/nnet_utils/nnet_dense_resource.h:33) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'layer2_out.V.data.V' (firmware/NN.cpp:35) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'layer3_out.V.data.V' (firmware/NN.cpp:42) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'layer4_out.V.data.V' (firmware/NN.cpp:49) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'out_local.V.data.V' (firmware/NN_axi.cpp:12) in dimension 1 completely.
# INFO: [XFORM 203-101] Partitioning array 'in_local.V.data.V' in dimension 1 completely.
# WARNING: [XFORM 203-104] Completely partitioning array 'data.V' (firmware/nnet_utils/nnet_dense_stream.h:29) accessed through non-constant indices on dimension 1 (firmware/nnet_utils/nnet_dense_resource.h:56:17), which may result in long runtime and suboptimal QoR due to large multiplexers. Please consider wrapping the array access into a function or using a register file core instead.
# INFO: [XFORM 203-721] Changing loop 'Loop_3_proc' (firmware/NN_axi.cpp:31) to a process function for dataflow in function 'NN_axi'.
# INFO: [XFORM 203-712] Applying dataflow to function 'NN', detected/extracted 4 process function(s):
# 	 'nnet::dense<nnet::array<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 800u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>'
# 	 'nnet::relu<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config3>'
# 	 'nnet::normalize<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>'
# 	 'nnet::dense<nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, 2u>, config5>'.
# INFO: [XFORM 203-712] Applying dataflow to function 'NN_axi', detected/extracted 4 process function(s):
# 	 'Block_codeRepl835_proc121'
# 	 'NN'
# 	 'Block__ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5EL9ap_o_mode3ELi0EELj800EEELi0EE5writeERKS7_.exit.i.0837_proc'
# 	 'Loop_3_proc'.
# INFO: [XFORM 203-401] Performing if-conversion on hyperblock to (firmware/nnet_utils/nnet_activation_stream.h:59:1) in function 'nnet::relu<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config3>'... converting 25 basic blocks.
# INFO: [XFORM 203-401] Performing if-conversion on hyperblock from (firmware/NN_axi.cpp:32:90) to (firmware/NN_axi.cpp:31:49) in function 'Loop_3_proc'... converting 10 basic blocks.
# INFO: [XFORM 203-401] Performing if-conversion on hyperblock from (firmware/NN_axi.cpp:22:25) to (firmware/NN_axi.cpp:20:41) in function 'Block_codeRepl835_proc121'... converting 10 basic blocks.
# INFO: [XFORM 203-11] Balancing expressions in function 'nnet::dense_wrapper<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_resource.h:23:17)...128 expression(s) balanced.
# INFO: [HLS 200-111] Finished Pre-synthesis Time (s): cpu = 00:02:12 ; elapsed = 00:02:15 . Memory (MB): peak = 1933.688 ; gain = 1511.621 ; free physical = 11389 ; free virtual = 266419
# WARNING: [XFORM 203-631] Renaming function 'nnet::relu<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, relu_config3>' to 'relu<array<ap_fixed,8u>,array<ap_fixed<17,17,5,3,0>,8u>,relu_config3>' (firmware/nnet_utils/nnet_activation_stream.h:41:1)
# WARNING: [XFORM 203-631] Renaming function 'nnet::normalize<nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config4>' to 'normalize<array<ap_fixed,8u>,array<ap_fixed<24,4,5,3,0>,8u>,config4>' (firmware/nnet_utils/nnet_batchnorm_stream.h:22:1)
# WARNING: [XFORM 203-631] Renaming function 'nnet::dense_wrapper<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' to 'dense_wrapper<ap_fixed<24, 4, 5, 3, 0>, ap_fixed<8, 5, 5, 3, 0>, config5>' (firmware/nnet_utils/nnet_dense_stream.h:13)
# WARNING: [XFORM 203-631] Renaming function 'nnet::dense_wrapper<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' to 'dense_wrapper<ap_fixed<14, 14, 5, 3, 0>, ap_fixed<17, 17, 5, 3, 0>, config2>' (firmware/nnet_utils/nnet_dense_stream.h:13)
# WARNING: [XFORM 203-631] Renaming function 'nnet::dense<nnet::array<ap_fixed<24, 4, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, nnet::array<ap_fixed<8, 5, (ap_q_mode)5, (ap_o_mode)3, 0>, 2u>, config5>' to 'dense<array<ap_fixed,8u>,array<ap_fixed<8,5,5,3,0>,2u>,config5>' (firmware/nnet_utils/nnet_dense_stream.h:36:1)
# WARNING: [XFORM 203-631] Renaming function 'nnet::dense<nnet::array<ap_fixed<14, 14, (ap_q_mode)5, (ap_o_mode)3, 0>, 800u>, nnet::array<ap_fixed<17, 17, (ap_q_mode)5, (ap_o_mode)3, 0>, 8u>, config2>' to 'dense<array<ap_fixed,800u>,array<ap_fixed<17,17,5,3,0>,8u>,config2>' (firmware/nnet_utils/nnet_dense_stream.h:36:39)
# WARNING: [XFORM 203-631] Renaming function 'Block__ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5EL9ap_o_mode3ELi0EELj800EEELi0EE5writeERKS7_.exit.i.0837_proc' to 'Block__ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5EL9ap_o_mode3E' (firmware/NN_axi.cpp:30:26)
# INFO: [XFORM 203-531] Rewinding loop 'ReuseLoop' (firmware/nnet_utils/nnet_dense_resource.h:129) in function 'dense_wrapper<ap_fixed<24, 4, 5, 3, 0>, ap_fixed<8, 5, 5, 3, 0>, config5>'.
# INFO: [XFORM 203-531] Rewinding loop 'ReuseLoop' (firmware/nnet_utils/nnet_dense_resource.h:43) in function 'dense_wrapper<ap_fixed<14, 14, 5, 3, 0>, ap_fixed<17, 17, 5, 3, 0>, config2>'.
# WARNING: [XFORM 203-561] Ignored multiple trip count directives for loop 'ReuseLoop' in function 'dense_wrapper<ap_fixed<24, 4, 5, 3, 0>, ap_fixed<8, 5, 5, 3, 0>, config5>'.
# WARNING: [XFORM 203-561] Ignored multiple trip count directives for loop 'ReuseLoop' in function 'dense_wrapper<ap_fixed<14, 14, 5, 3, 0>, ap_fixed<17, 17, 5, 3, 0>, config2>'.
# INFO: [HLS 200-111] Finished Architecture Synthesis Time (s): cpu = 00:03:52 ; elapsed = 00:03:55 . Memory (MB): peak = 1933.688 ; gain = 1511.621 ; free physical = 10939 ; free virtual = 266101
# INFO: [HLS 200-10] Starting hardware synthesis ...
# INFO: [HLS 200-10] Synthesizing 'NN_axi' ...
# WARNING: [SYN 201-103] Legalizing function name 'dense_wrapper<ap_fixed<14, 14, 5, 3, 0>, ap_fixed<17, 17, 5, 3, 0>, config2>' to 'dense_wrapper_ap_fixed_14_14_5_3_0_ap_fixed_17_17_5_3_0_config2_s'.
# WARNING: [SYN 201-103] Legalizing function name 'dense<array<ap_fixed,800u>,array<ap_fixed<17,17,5,3,0>,8u>,config2>' to 'dense_array_ap_fixed_800u_array_ap_fixed_17_17_5_3_0_8u_config2_s'.
# WARNING: [SYN 201-103] Legalizing function name 'relu<array<ap_fixed,8u>,array<ap_fixed<17,17,5,3,0>,8u>,relu_config3>' to 'relu_array_ap_fixed_8u_array_ap_fixed_17_17_5_3_0_8u_relu_config3_s'.
# WARNING: [SYN 201-103] Legalizing function name 'normalize<array<ap_fixed,8u>,array<ap_fixed<24,4,5,3,0>,8u>,config4>' to 'normalize_array_ap_fixed_8u_array_ap_fixed_24_4_5_3_0_8u_config4_s'.
# WARNING: [SYN 201-103] Legalizing function name 'dense_wrapper<ap_fixed<24, 4, 5, 3, 0>, ap_fixed<8, 5, 5, 3, 0>, config5>' to 'dense_wrapper_ap_fixed_24_4_5_3_0_ap_fixed_8_5_5_3_0_config5_s'.
# WARNING: [SYN 201-103] Legalizing function name 'dense<array<ap_fixed,8u>,array<ap_fixed<8,5,5,3,0>,2u>,config5>' to 'dense_array_ap_fixed_8u_array_ap_fixed_8_5_5_3_0_2u_config5_s'.
# WARNING: [SYN 201-103] Legalizing function name 'Block__ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5EL9ap_o_mode3E' to 'Block_ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5EL9ap_o_mode3E'.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'Block_codeRepl835_proc121'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 439.91 seconds; current allocated memory: 547.162 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 6.89 seconds; current allocated memory: 567.183 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'dense_wrapper_ap_fixed_14_14_5_3_0_ap_fixed_17_17_5_3_0_config2_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining loop 'ReuseLoop'.
# INFO: [SCHED 204-61] Pipelining result : Target II = 1, Final II = 1, Depth = 5.
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 13.26 seconds; current allocated memory: 581.224 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 4.97 seconds; current allocated memory: 604.329 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'dense_array_ap_fixed_800u_array_ap_fixed_17_17_5_3_0_8u_config2_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 5.16 seconds; current allocated memory: 609.518 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 1.98 seconds; current allocated memory: 620.321 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'relu_array_ap_fixed_8u_array_ap_fixed_17_17_5_3_0_8u_relu_config3_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining function 'relu<array<ap_fixed,8u>,array<ap_fixed<17,17,5,3,0>,8u>,relu_config3>'.
# INFO: [SCHED 204-61] Pipelining result : Target II = 1, Final II = 1, Depth = 2.
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 2.56 seconds; current allocated memory: 621.697 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 0.07 seconds; current allocated memory: 621.966 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'normalize_array_ap_fixed_8u_array_ap_fixed_24_4_5_3_0_8u_config4_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining function 'normalize<array<ap_fixed,8u>,array<ap_fixed<24,4,5,3,0>,8u>,config4>'.
# INFO: [SCHED 204-61] Pipelining result : Target II = 8, Final II = 8, Depth = 8.
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 0.13 seconds; current allocated memory: 622.257 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Starting global binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 0.1 seconds; current allocated memory: 622.596 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'dense_wrapper_ap_fixed_24_4_5_3_0_ap_fixed_8_5_5_3_0_config5_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining loop 'ReuseLoop'.
# INFO: [SCHED 204-61] Pipelining result : Target II = 1, Final II = 1, Depth = 4.
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 0.12 seconds; current allocated memory: 622.848 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 0.08 seconds; current allocated memory: 623.219 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'dense_array_ap_fixed_8u_array_ap_fixed_8_5_5_3_0_2u_config5_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 0.12 seconds; current allocated memory: 623.371 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 0.04 seconds; current allocated memory: 623.542 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'NN'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 0.12 seconds; current allocated memory: 625.254 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 2.07 seconds; current allocated memory: 634.207 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'Block_ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5EL9ap_o_mode3E'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 1.79 seconds; current allocated memory: 635.509 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 0.01 seconds; current allocated memory: 635.569 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'Loop_3_proc'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 0.03 seconds; current allocated memory: 635.780 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 0.08 seconds; current allocated memory: 636.086 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'NN_axi'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111]  Elapsed time: 0.46 seconds; current allocated memory: 639.651 MB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111]  Elapsed time: 3.49 seconds; current allocated memory: 655.621 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'Block_codeRepl835_proc121'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-104] Estimated max fanout for 'Block_codeRepl835_proc121' is 12004 from HDL expression: (~((icmp_ln181_fu_13344_p2 == 1'd1) & (io_acc_block_signal_op4097 == 1'b0)) & (icmp_ln181_fu_13344_p2 == 1'd1) & (1'b1 == ap_CS_fsm_state8))
# INFO: [RTGEN 206-100] Generating core module 'NN_axi_fpext_32ns_64_2_1': 1 instance(s).
# INFO: [RTGEN 206-100] Finished creating RTL model for 'Block_codeRepl835_proc121'.
# INFO: [HLS 200-111]  Elapsed time: 5.99 seconds; current allocated memory: 689.673 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_wrapper_ap_fixed_14_14_5_3_0_ap_fixed_17_17_5_3_0_config2_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-104] Estimated max fanout for 'dense_wrapper_ap_fixed_14_14_5_3_0_ap_fixed_17_17_5_3_0_config2_s' is 22400 from HDL expression: (do_init_reg_7073 == 1'd0)
# INFO: [RTGEN 206-100] Generating core module 'NN_axi_mul_mul_14s_6s_20_1_1': 127 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'NN_axi_mux_646_14_1_1': 1 instance(s).
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_wrapper_ap_fixed_14_14_5_3_0_ap_fixed_17_17_5_3_0_config2_s'.
# INFO: [HLS 200-111]  Elapsed time: 8.25 seconds; current allocated memory: 772.983 MB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_array_ap_fixed_800u_array_ap_fixed_17_17_5_3_0_8u_config2_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-104] Estimated max fanout for 'dense_array_ap_fixed_800u_array_ap_fixed_17_17_5_3_0_8u_config2_s' is 12001 from HDL expression: (~((real_start == 1'b0) | (io_acc_block_signal_op3 == 1'b0) | (ap_done_reg == 1'b1)) & (1'b1 == ap_CS_fsm_state1))
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_array_ap_fixed_800u_array_ap_fixed_17_17_5_3_0_8u_config2_s'.
# INFO: [HLS 200-111]  Elapsed time: 34.63 seconds; current allocated memory: 1.626 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'relu_array_ap_fixed_8u_array_ap_fixed_17_17_5_3_0_8u_relu_config3_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'relu_array_ap_fixed_8u_array_ap_fixed_17_17_5_3_0_8u_relu_config3_s'.
# INFO: [HLS 200-111]  Elapsed time: 3.94 seconds; current allocated memory: 1.634 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'normalize_array_ap_fixed_8u_array_ap_fixed_24_4_5_3_0_8u_config4_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'normalize_array_ap_fixed_8u_array_ap_fixed_24_4_5_3_0_8u_config4_s'.
# INFO: [HLS 200-111]  Elapsed time: 0.63 seconds; current allocated memory: 1.636 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_wrapper_ap_fixed_24_4_5_3_0_ap_fixed_8_5_5_3_0_config5_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Generating core module 'NN_axi_mul_mul_24s_6s_30_1_1': 1 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'NN_axi_mux_83_24_1_1': 1 instance(s).
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_wrapper_ap_fixed_24_4_5_3_0_ap_fixed_8_5_5_3_0_config5_s'.
# INFO: [HLS 200-111]  Elapsed time: 0.66 seconds; current allocated memory: 1.637 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_array_ap_fixed_8u_array_ap_fixed_8_5_5_3_0_2u_config5_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_array_ap_fixed_8u_array_ap_fixed_8_5_5_3_0_2u_config5_s'.
# INFO: [HLS 200-111]  Elapsed time: 0.67 seconds; current allocated memory: 1.639 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'NN'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'NN'.
# INFO: [HLS 200-111]  Elapsed time: 2.86 seconds; current allocated memory: 1.654 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'Block_ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5EL9ap_o_mode3E'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'Block_ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5EL9ap_o_mode3E'.
# INFO: [HLS 200-111]  Elapsed time: 2.56 seconds; current allocated memory: 1.664 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'Loop_3_proc'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'Loop_3_proc'.
# INFO: [HLS 200-111]  Elapsed time: 0.56 seconds; current allocated memory: 1.665 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'NN_axi'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-500] Setting interface mode on port 'NN_axi/in_data' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'NN_axi/in_last_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'NN_axi/out_data' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on port 'NN_axi/out_last_V' to 'axis' (register, both mode).
# INFO: [RTGEN 206-500] Setting interface mode on function 'NN_axi' to 'ap_ctrl_none'.
# WARNING: [HLS 200-631] Ignoring ap_ctrl_none interface for NN_axi due to Block__ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5EL9ap_o_mode3E with non-FIFO I/O
# INFO: [SYN 201-210] Renamed object name 'start_for_Block_ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5EL9ap_o_mode3E_U0' to 'start_for_Block_ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5ELbkb' due to the length limit 80
# INFO: [RTGEN 206-100] Finished creating RTL model for 'NN_axi'.
# INFO: [HLS 200-111]  Elapsed time: 13.54 seconds; current allocated memory: 1.695 GB.
# INFO: [HLS 200-790] **** Loop Constraint Status: All loop constraints were satisfied.
# INFO: [HLS 200-789] **** Estimated Fmax: 361.25 MHz
# INFO: [RTMG 210-279] Implementing memory 'dense_wrapper_ap_fixed_14_14_5_3_0_ap_fixed_17_17_5_3_0_config2_s_w2_V_rom' using auto ROMs.
# INFO: [RTMG 210-279] Implementing memory 'dense_wrapper_ap_fixed_24_4_5_3_0_ap_fixed_8_5_5_3_0_config5_s_outidx_rom' using distributed ROMs.
# INFO: [RTMG 210-279] Implementing memory 'dense_wrapper_ap_fixed_24_4_5_3_0_ap_fixed_8_5_5_3_0_config5_s_w5_V_rom' using distributed ROMs.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_relu_array_ap_fixed_8u_array_ap_fixed_17_17_5_3_0_8u_relu_config3_U0_U(start_for_relu_array_ap_fixed_8u_array_ap_fixed_17_17_5_3_0_8u_relu_config3_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_normalize_array_ap_fixed_8u_array_ap_fixed_24_4_5_3_0_8u_config4_U0_U(start_for_normalize_array_ap_fixed_8u_array_ap_fixed_24_4_5_3_0_8u_config4_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_dense_array_ap_fixed_8u_array_ap_fixed_8_5_5_3_0_2u_config5_U0_U(start_for_dense_array_ap_fixed_8u_array_ap_fixed_8_5_5_3_0_2u_config5_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'is_last_1_i_0_loc_channel_U(fifo_w1_d2_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'tmp_data_0_V_U(fifo_w8_d2_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'tmp_data_1_V_U(fifo_w8_d2_A)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_NN_U0_U(start_for_NN_U0)' using Shift Registers.
# INFO: [RTMG 210-285] Implementing FIFO 'start_for_Block_ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5ELbkb_U(start_for_Block_ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5ELbkb)' using Shift Registers.
# INFO: [HLS 200-111] Finished generating all RTL models Time (s): cpu = 00:09:47 ; elapsed = 00:09:59 . Memory (MB): peak = 2917.672 ; gain = 2495.605 ; free physical = 8884 ; free virtual = 264899
# INFO: [VHDL 208-304] Generating VHDL RTL for NN_axi.
# INFO: [VLOG 209-307] Generating Verilog RTL for NN_axi.
# ***** C/RTL SYNTHESIS COMPLETED IN 0h9m56s *****
# ***** VIVADO SYNTHESIS *****
#
# ****** Vivado v2020.1.1 (64-bit)
#   **** SW Build 2960000 on Wed Aug  5 22:57:21 MDT 2020
#   **** IP Build 2956692 on Thu Aug  6 01:41:30 MDT 2020
#     ** Copyright 1986-2020 Xilinx, Inc. All Rights Reserved.
#
# source vivado_synth.tcl
# # set tcldir [file dirname [info script]]
# # source [file join $tcldir project.tcl]
# ## variable project_name
# ## set project_name "NN"
# ## variable backend
# ## set backend "vivadoaccelerator"
# ## variable part
# ## set part "xczu49dr-ffvf1760-2-e"
# ## variable clock_period
# ## set clock_period 3.225
# ## variable clock_uncertainty
# ## set clock_uncertainty 12.5%
# ## variable version
# ## set version "1.0.0"
# ## set bit_width_hls_output 32
# ## set bit_width_hls_input 32
# # add_files ${project_name}_prj/solution1/syn/vhdl
# # synth_design -top ${project_name} -part $part
# Command: synth_design -top NN -part xczu49dr-ffvf1760-2-e
# Starting synth_design
# Attempting to get a license for feature 'Synthesis' and/or device 'xczu49dr'
# INFO: [Common 17-349] Got license for feature 'Synthesis' and/or device 'xczu49dr'
# ...
# |140   |  layer2_out_V_data_1_V_U                                                            |fifo_w17_d1_A_0                                                                                                                                                                            |    33|
# |141   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg_36                                                                                                                                                                  |    25|
# |142   |  layer2_out_V_data_2_V_U                                                            |fifo_w17_d1_A_1                                                                                                                                                                            |    43|
# |143   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg_35                                                                                                                                                                  |    33|
# |144   |  layer2_out_V_data_3_V_U                                                            |fifo_w17_d1_A_2                                                                                                                                                                            |    33|
# |145   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg_34                                                                                                                                                                  |    25|
# |146   |  layer2_out_V_data_4_V_U                                                            |fifo_w17_d1_A_3                                                                                                                                                                            |    34|
# |147   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg_33                                                                                                                                                                  |    25|
# |148   |  layer2_out_V_data_5_V_U                                                            |fifo_w17_d1_A_4                                                                                                                                                                            |    33|
# |149   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg_32                                                                                                                                                                  |    25|
# |150   |  layer2_out_V_data_6_V_U                                                            |fifo_w17_d1_A_5                                                                                                                                                                            |    33|
# |151   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg_31                                                                                                                                                                  |    25|
# |152   |  layer2_out_V_data_7_V_U                                                            |fifo_w17_d1_A_6                                                                                                                                                                            |    34|
# |153   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg_30                                                                                                                                                                  |    26|
# |154   |  layer3_out_V_data_0_V_U                                                            |fifo_w17_d1_A_7                                                                                                                                                                            |    25|
# |155   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg_29                                                                                                                                                                  |    17|
# |156   |  layer3_out_V_data_1_V_U                                                            |fifo_w17_d1_A_8                                                                                                                                                                            |    27|
# |157   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg_28                                                                                                                                                                  |    17|
# |158   |  layer3_out_V_data_2_V_U                                                            |fifo_w17_d1_A_9                                                                                                                                                                            |    26|
# |159   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg_27                                                                                                                                                                  |    17|
# |160   |  layer3_out_V_data_3_V_U                                                            |fifo_w17_d1_A_10                                                                                                                                                                           |    25|
# |161   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg_26                                                                                                                                                                  |    17|
# |162   |  layer3_out_V_data_4_V_U                                                            |fifo_w17_d1_A_11                                                                                                                                                                           |    25|
# |163   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg_25                                                                                                                                                                  |    17|
# |164   |  layer3_out_V_data_5_V_U                                                            |fifo_w17_d1_A_12                                                                                                                                                                           |    25|
# |165   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg_24                                                                                                                                                                  |    17|
# |166   |  layer3_out_V_data_6_V_U                                                            |fifo_w17_d1_A_13                                                                                                                                                                           |    25|
# |167   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg_23                                                                                                                                                                  |    17|
# |168   |  layer3_out_V_data_7_V_U                                                            |fifo_w17_d1_A_14                                                                                                                                                                           |    28|
# |169   |    U_fifo_w17_d1_A_shiftReg                                                         |fifo_w17_d1_A_shiftReg                                                                                                                                                                     |    17|
# |170   |  layer4_out_V_data_0_V_U                                                            |fifo_w24_d1_A                                                                                                                                                                              |     9|
# |171   |  layer4_out_V_data_1_V_U                                                            |fifo_w24_d1_A_15                                                                                                                                                                           |    13|
# |172   |  layer4_out_V_data_2_V_U                                                            |fifo_w24_d1_A_16                                                                                                                                                                           |     8|
# |173   |  layer4_out_V_data_3_V_U                                                            |fifo_w24_d1_A_17                                                                                                                                                                           |     9|
# |174   |  layer4_out_V_data_4_V_U                                                            |fifo_w24_d1_A_18                                                                                                                                                                           |    30|
# |175   |    U_fifo_w24_d1_A_shiftReg                                                         |fifo_w24_d1_A_shiftReg_22                                                                                                                                                                  |    22|
# |176   |  layer4_out_V_data_5_V_U                                                            |fifo_w24_d1_A_19                                                                                                                                                                           |     9|
# |177   |  layer4_out_V_data_6_V_U                                                            |fifo_w24_d1_A_20                                                                                                                                                                           |    30|
# |178   |    U_fifo_w24_d1_A_shiftReg                                                         |fifo_w24_d1_A_shiftReg                                                                                                                                                                     |    22|
# |179   |  layer4_out_V_data_7_V_U                                                            |fifo_w24_d1_A_21                                                                                                                                                                           |     8|
# |180   |  normalize_array_ap_fixed_8u_array_ap_fixed_24_4_5_3_0_8u_config4_U0                |normalize_array_ap_fixed_8u_array_ap_fixed_24_4_5_3_0_8u_config4_s                                                                                                                         |   280|
# |181   |  relu_array_ap_fixed_8u_array_ap_fixed_17_17_5_3_0_8u_relu_config3_U0               |relu_array_ap_fixed_8u_array_ap_fixed_17_17_5_3_0_8u_relu_config3_s                                                                                                                        |   258|
# |182   |  start_for_dense_array_ap_fixed_8u_array_ap_fixed_8_5_5_3_0_2u_config5_U0_U         |start_for_dense_array_ap_fixed_8u_array_ap_fixed_8_5_5_3_0_2u_config5_U0                                                                                                                   |    12|
# |183   |  start_for_normalize_array_ap_fixed_8u_array_ap_fixed_24_4_5_3_0_8u_config4_U0_U    |start_for_normalize_array_ap_fixed_8u_array_ap_fixed_24_4_5_3_0_8u_config4_U0                                                                                                              |    13|
# |184   |  start_for_relu_array_ap_fixed_8u_array_ap_fixed_17_17_5_3_0_8u_relu_config3_U0_U   |start_for_relu_array_ap_fixed_8u_array_ap_fixed_17_17_5_3_0_8u_relu_config3_U0                                                                                                             |    16|
# +------+-------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------+
# ---------------------------------------------------------------------------------
# Finished Writing Synthesis Report : Time (s): cpu = 00:01:21 ; elapsed = 00:01:53 . Memory (MB): peak = 2927.020 ; gain = 819.453 ; free physical = 1531 ; free virtual = 257902
# ---------------------------------------------------------------------------------
# Synthesis finished with 0 errors, 0 critical warnings and 0 warnings.
# Synthesis Optimization Runtime : Time (s): cpu = 00:01:25 ; elapsed = 00:01:57 . Memory (MB): peak = 2930.930 ; gain = 823.363 ; free physical = 7243 ; free virtual = 263610
# Synthesis Optimization Complete : Time (s): cpu = 00:01:25 ; elapsed = 00:01:57 . Memory (MB): peak = 2930.930 ; gain = 823.363 ; free physical = 7260 ; free virtual = 263613
# INFO: [Project 1-571] Translating synthesized netlist
# Netlist sorting complete. Time (s): cpu = 00:00:00.71 ; elapsed = 00:00:00.71 . Memory (MB): peak = 2937.020 ; gain = 0.000 ; free physical = 7196 ; free virtual = 263549
# INFO: [Netlist 29-17] Analyzing 14497 Unisim elements for replacement
# INFO: [Netlist 29-28] Unisim Transformation completed in 2 CPU seconds
# INFO: [Project 1-570] Preparing netlist for logic optimization
# INFO: [Opt 31-138] Pushed 0 inverter(s) to 0 load pin(s).
# Netlist sorting complete. Time (s): cpu = 00:00:00.02 ; elapsed = 00:00:00.02 . Memory (MB): peak = 3178.465 ; gain = 0.000 ; free physical = 6981 ; free virtual = 263338
# INFO: [Project 1-111] Unisim Transformation Summary:
#   A total of 12142 instances were transformed.
#   BUFG => BUFGCE: 1 instance
#   DSP48E2 => DSP48E2 (DSP_ALU, DSP_A_B_DATA, DSP_C_DATA, DSP_MULTIPLIER, DSP_M_DATA, DSP_OUTPUT, DSP_PREADD, DSP_PREADD_DATA): 134 instances
#   IBUF => IBUF (IBUFCTRL, INBUF): 12007 instances
#
# INFO: [Common 17-83] Releasing license: Synthesis
# 181 Infos, 0 Warnings, 0 Critical Warnings and 0 Errors encountered.
# synth_design completed successfully
# synth_design: Time (s): cpu = 00:01:42 ; elapsed = 00:02:18 . Memory (MB): peak = 3178.465 ; gain = 1077.109 ; free physical = 7148 ; free virtual = 263504
# # report_utilization -file vivado_synth.rpt
# INFO: [Common 17-206] Exiting Vivado at Fri Oct  4 08:33:08 2024...
# ***** VIVADO SYNTHESIS COMPLETED IN 0h2m38s *****
# INFO: [HLS 200-112] Total elapsed time: 758.5 seconds; peak allocated memory: 1.695 GB.
# INFO: [Common 17-206] Exiting vivado_hls at Fri Oct  4 08:33:20 2024...
# Cosim report not found.
# Timing report not found.
# Cosim report not found.
# Timing report not found.

# %% [markdown]
# ## Check the report

# %%
#print(reports)

print('HLS')
print('   BRAM {:8d} ({:8d}, {:6.2f}%)'.format(int(reports['CSynthesisReport']['BRAM_18K']), int(reports['CSynthesisReport']['AvailableBRAM_18K']), int(reports['CSynthesisReport']['BRAM_18K'])*100/int(reports['CSynthesisReport']['AvailableBRAM_18K'])))
print('    DSP {:8d} ({:8d}, {:6.2f}%)'.format(int(reports['CSynthesisReport']['DSP']), int(reports['CSynthesisReport']['AvailableDSP']), int(reports['CSynthesisReport']['DSP'])*100/int(reports['CSynthesisReport']['AvailableDSP'])))
print('     FF {:8d} ({:8d}, {:6.2f}%)'.format(int(reports['CSynthesisReport']['FF']), int(reports['CSynthesisReport']['AvailableFF']), int(reports['CSynthesisReport']['FF'])*100/int(reports['CSynthesisReport']['AvailableFF'])))
print('    LUT {:8d} ({:8d}, {:6.2f}%)'.format(int(reports['CSynthesisReport']['LUT']), int(reports['CSynthesisReport']['AvailableLUT']), int(reports['CSynthesisReport']['LUT'])*100/int(reports['CSynthesisReport']['AvailableLUT'])))
print('SYN')
print('   BRAM {:8d} ({:8d}, {:6.2f}%)'.format(int(reports['VivadoSynthReport']['BRAM_18K']), int(reports['CSynthesisReport']['AvailableBRAM_18K']), int(reports['VivadoSynthReport']['BRAM_18K'])*100/int(reports['CSynthesisReport']['AvailableBRAM_18K'])))
print('    DSP {:8d} ({:8d}, {:6.2f}%)'.format(int(reports['VivadoSynthReport']['DSP48E']), int(reports['CSynthesisReport']['AvailableDSP']), int(reports['VivadoSynthReport']['DSP48E'])*100/int(reports['CSynthesisReport']['AvailableDSP'])))
print('     FF {:8d} ({:8d}, {:6.2f}%)'.format(int(reports['VivadoSynthReport']['FF']), int(reports['CSynthesisReport']['AvailableFF']), int(reports['VivadoSynthReport']['FF'])*100/int(reports['CSynthesisReport']['AvailableFF'])))
print('    LUT {:8d} ({:8d}, {:6.2f}%)'.format(int(reports['VivadoSynthReport']['LUT']), int(reports['CSynthesisReport']['AvailableLUT']), int(reports['VivadoSynthReport']['LUT'])*100/int(reports['CSynthesisReport']['AvailableLUT'])))
# Out:
# HLS
#    BRAM       22 (    2160,   1.02%)
#     DSP      129 (    4272,   3.02%)
#      FF    77642 (  850560,   9.13%)
#     LUT   102155 (  425280,  24.02%)
# SYN
#    BRAM        0 (    2160,   0.00%)
#     DSP      134 (    4272,   3.14%)
#      FF    47039 (  850560,   5.53%)
#     LUT    22276 (  425280,   5.24%)

# %%
df_hls = pd.DataFrame([reports['CSynthesisReport']])
hls_csv_file = 'hls_report.csv'
hls_csv_file_exists = os.path.isfile(hls_csv_file)
df_hls.to_csv(hls_csv_file, mode='a', index=False, header=not hls_csv_file_exists)
df_hls_loaded = pd.read_csv(hls_csv_file)
df_hls_loaded
# Out:
#    TargetClockPeriod  EstimatedClockPeriod  BestLatency  WorstLatency  \
# 0               3.22                 2.768          874           875
# 1               3.22                 2.799          832           833
# 2               3.22                 2.768         5601          5601
# 3               3.22                 2.768         5601          5601
# 4               3.22                 2.768         5601          5601
# 5               3.22                 2.768         5601          5601
# 6               3.22                 2.768         5601          5601
# 7               3.22                 2.768         5601          5601
#
#    IntervalMin  IntervalMax  BRAM_18K  DSP      FF      LUT  URAM  \
# 0          875          876       645  106  196393   205339     0
# 1          833          834       757  610  909414  1142446     0
# 2         5602         5602        67  410   86340   106817     0
# 3         5602         5602        67  410   86340   106817     0
# 4         5602         5602        67  410   86340   106817     0
# 5         5602         5602        67  401   86442   107039     0
# 6         5602         5602        22  129   77673   102178     0
# 7         5602         5602        22  129   77642   102155     0
#
#    AvailableBRAM_18K  AvailableDSP  AvailableFF  AvailableLUT  AvailableURAM
# 0               2160          4272       850560        425280             80
# 1               2160          4272       850560        425280             80
# 2               2160          4272       850560        425280             80
# 3               2160          4272       850560        425280             80
# 4               2160          4272       850560        425280             80
# 5               2160          4272       850560        425280             80
# 6               2160          4272       850560        425280             80
# 7               2160          4272       850560        425280             80

# %%
df_syn = pd.DataFrame([reports['VivadoSynthReport']])
syn_csv_file = 'syn_report.csv'
syn_csv_file_exists = os.path.isfile(syn_csv_file)
df_syn.to_csv(syn_csv_file, mode='a', index=False, header=not syn_csv_file_exists)
df_syn_loaded = pd.read_csv(syn_csv_file)
df_syn_loaded
# Out:
#      LUT     FF  BRAM_18K  URAM  DSP48E
# 0  89713  58349       156     0     106
# 1  74760  63230       156     0     610
# 2  28193  46864         0     0     310
# 3  28193  46864         0     0     310
# 4  28193  46864         0     0     310
# 5  30325  48323         0     0     407
# 6  22875  47005         0     0     135
# 7  22276  47039         0     0     134

# %%
hls4ml.report.read_vivado_report(output_dir)
# Out:
# Found 1 solution(s) in ../hls4ml_projects/sl-100_ws-400_date-20230529/NN_prj.
# Reports for solution "solution1":
#
# C simulation report not found.
# SYNTHESIS REPORT:
# ================================================================
# == Vivado HLS Report for 'NN_axi'
# ================================================================
# * Date:           Fri Oct  4 08:30:01 2024
#
# * Version:        2020.1.1 (Build 2951007 on Wed Aug 05 23:24:06 MDT 2020)
# * Project:        NN_prj
# * Solution:       solution1
# * Product family: zynquplus
# * Target device:  xczu49dr-ffvf1760-2-e
#
#
# ================================================================
# == Performance Estimates
# ================================================================
# + Timing:
#     * Summary:
#     +--------+---------+----------+------------+
#     |  Clock |  Target | Estimated| Uncertainty|
#     +--------+---------+----------+------------+
#     |ap_clk  | 3.22 ns | 2.768 ns |   0.40 ns  |
#     +--------+---------+----------+------------+
#
# + Latency:
#     * Summary:
#     +---------+---------+-----------+-----------+------+------+----------+
#     |  Latency (cycles) |   Latency (absolute)  |   Interval  | Pipeline |
#     |   min   |   max   |    min    |    max    |  min |  max |   Type   |
#     +---------+---------+-----------+-----------+------+------+----------+
#     |     5601|     5601| 18.063 us | 18.063 us |  5602|  5602| dataflow |
#     +---------+---------+-----------+-----------+------+------+----------+
#
#     + Detail:
#         * Instance:
#         +------------------------------------------------------------------------------------+---------------------------------------------------------------------------------+---------+---------+-----------+-----------+------+------+----------+
#         |                                                                                    |                                                                                 |  Latency (cycles) |   Latency (absolute)  |   Interval  | Pipeline |
#         |                                      Instance                                      |                                      Module                                     |   min   |   max   |    min    |    max    |  min |  max |   Type   |
#         +------------------------------------------------------------------------------------+---------------------------------------------------------------------------------+---------+---------+-----------+-----------+------+------+----------+
#         |NN_U0                                                                               |NN                                                                               |       54|       55|  0.174 us |  0.177 us |    55|    56| dataflow |
#         |Block_codeRepl835_proc121_U0                                                        |Block_codeRepl835_proc121                                                        |     5601|     5601| 18.063 us | 18.063 us |  5601|  5601|   none   |
#         |Loop_3_proc_U0                                                                      |Loop_3_proc                                                                      |       13|       13| 41.925 ns | 41.925 ns |    13|    13|   none   |
#         |Block_ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5EL9ap_o_mode3E_U0  |Block_ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5EL9ap_o_mode3E  |        0|        0|    0 ns   |    0 ns   |     0|     0|   none   |
#         +------------------------------------------------------------------------------------+---------------------------------------------------------------------------------+---------+---------+-----------+-----------+------+------+----------+
#
#         * Loop:
#         N/A
#
#
#
# ================================================================
# == Utilization Estimates
# ================================================================
# * Summary:
# +-----------------+---------+-------+--------+--------+-----+
# |       Name      | BRAM_18K| DSP48E|   FF   |   LUT  | URAM|
# +-----------------+---------+-------+--------+--------+-----+
# |DSP              |        -|      -|       -|       -|    -|
# |Expression       |        -|      -|       0|      12|    -|
# |FIFO             |        0|      -|    4025|   20896|    -|
# |Instance         |       22|    129|   73615|   81229|    -|
# |Memory           |        -|      -|       -|       -|    -|
# |Multiplexer      |        -|      -|       -|      18|    -|
# |Register         |        -|      -|       2|       -|    -|
# +-----------------+---------+-------+--------+--------+-----+
# |Total            |       22|    129|   77642|  102155|    0|
# +-----------------+---------+-------+--------+--------+-----+
# |Available        |     2160|   4272|  850560|  425280|   80|
# +-----------------+---------+-------+--------+--------+-----+
# |Utilization (%)  |        1|      3|       9|      24|    0|
# +-----------------+---------+-------+--------+--------+-----+
#
# + Detail:
#     * Instance:
#     +------------------------------------------------------------------------------------+---------------------------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |                                      Instance                                      |                                      Module                                     | BRAM_18K| DSP48E|   FF  |  LUT  | URAM|
#     +------------------------------------------------------------------------------------+---------------------------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |Block_ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5EL9ap_o_mode3E_U0  |Block_ZN3hls6streamIN4nnet5arrayI8ap_fixedILi14ELi14EL9ap_q_mode5EL9ap_o_mode3E  |        0|      0|     18|     49|    0|
#     |Block_codeRepl835_proc121_U0                                                        |Block_codeRepl835_proc121                                                        |        0|      0|  22837|  26876|    0|
#     |Loop_3_proc_U0                                                                      |Loop_3_proc                                                                      |        0|      0|    197|    930|    0|
#     |NN_U0                                                                               |NN                                                                               |       22|    129|  50563|  53374|    0|
#     +------------------------------------------------------------------------------------+---------------------------------------------------------------------------------+---------+-------+-------+-------+-----+
#     |Total                                                                               |                                                                                 |       22|    129|  73615|  81229|    0|
#     +------------------------------------------------------------------------------------+---------------------------------------------------------------------------------+---------+-------+-------+-------+-----+
#
# Co-simulation report not found.

# %%
# !echo "$PWD/../hls4ml_projects/"
# !ls "$PWD/../hls4ml_projects/"
# Out:
# /extras/home/gdg/research/projects/quantum/qick_dev/submodules/ml-quantum-readout/notebooks/../hls4ml_projects/
# sl-100_ws-400_date-20230529	    sl-100_ws-400_date-20240528
# sl-100_ws-400_date-20230529.tar.gz  sl-100_ws-400_date-20240528.tar.gz
